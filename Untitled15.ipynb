# %%
import numpy as np

# %%
vect_2016 = np.loadtxt('2016.txt')

# %%
vect_2018 = np.loadtxt('2018.txt')

# %%
vect_2018.shape
# Out:
# (6209920, 9)

# %%
# %matplotlib inline  
import matplotlib.pyplot as plt
step  = 500000
first = 0
cl = ['rs', 'cs', 'ms', 'gs', 'ys', 'ks', 'bs']
fig = plt.figure(figsize=(20, 12))
ax = plt.subplot(111)
ax.plot(vect_2016[::100, 0], vect_2016[::100, 1], cl[0])

ax.plot(vect_2018[::100, 0], vect_2018[::100, 1], cl[1])

    
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend(['2016', '2018'])
ax.grid()
xax = ax.xaxis   # или xax = ax.get_xaxis()
xlocs = xax.get_ticklocs()
ax.set_xticks(xlocs)
# Out:
# [<matplotlib.axis.XTick at 0x24f804bfa20>,
#  <matplotlib.axis.XTick at 0x24f804bf278>,
#  <matplotlib.axis.XTick at 0x24f804bf0b8>,
#  <matplotlib.axis.XTick at 0x24f805a2400>,
#  <matplotlib.axis.XTick at 0x24f805a2c18>,
#  <matplotlib.axis.XTick at 0x24f805a2cf8>,
#  <matplotlib.axis.XTick at 0x24f805b1198>,
#  <matplotlib.axis.XTick at 0x24f805b1668>,
#  <matplotlib.axis.XTick at 0x24f805b1ba8>,
#  <matplotlib.axis.XTick at 0x24f805b9160>]

# %%
x_min_2016 = min(vect_2016[:, 0])
x_max_2016 = max(vect_2016[:, 0])
x_min_2018 = min(vect_2018[:, 0])
x_max_2018 = max(vect_2018[:, 0])

y_min_2016 = min(vect_2016[:, 1])
y_max_2016 = max(vect_2016[:, 1])
y_min_2018 = min(vect_2018[:, 1])
y_max_2018 = max(vect_2018[:, 1])

x_min  = max(x_min_2016, x_min_2018)
x_max  = min(x_max_2016, x_max_2018)
y_min  = max(y_min_2016, y_min_2018)
y_max  = min(y_max_2016, y_max_2018)

x_2016 = vect_2016[:, 0]
x_2016_idx = np.array([(x_2016 >= x_min) & (x_2016 <= x_max)]).reshape(-1, )

y_2016 = vect_2016[:, 1]
y_2016_idx = np.array([(y_2016 >= y_min) & (y_2016 <= y_max)]).reshape(-1, )

x_2018 = vect_2018[:, 0]
x_2018_idx = np.array([(x_2018 >= x_min) & (x_2018 <= x_max)]).reshape(-1, )

y_2018= vect_2018[:, 1]
y_2018_idx = np.array([(y_2018 >= y_min) & (y_2018 <= y_max)]).reshape(-1, )



vect_2016_work = vect_2016[(x_2016_idx == True) & (y_2016_idx == True)]
vect_2018_work = vect_2018[(x_2018_idx == True) & (y_2018_idx == True)]
vect_2016_work.shape, vect_2018_work.shape
# Out:
# ((3196673, 9), (6206696, 9))

# %%
x_min_2016, x_max_2016, x_min_2018, x_max_2018
# Out:
# (39.170244, 39.177513, 39.170151, 39.176993)

# %%
y_min_2016, y_max_2016, y_min_2018, y_max_2018
# Out:
# (47.027058, 47.031717, 47.027841, 47.031657)

# %%
x_min_20161 = min(vect_2016_work[:, 0])
x_max_20161 = max(vect_2016_work[:, 0])
x_min_20181 = min(vect_2018_work[:, 0])
x_max_20181 = max(vect_2018_work[:, 0])

# %%
y_min_20161 = min(vect_2016_work[:, 1])
y_max_20161 = max(vect_2016_work[:, 1])
y_min_20181 = min(vect_2018_work[:, 1])
y_max_20181 = max(vect_2018_work[:, 1])

# %%
x_min_2016, x_max_2016, x_min_2018, x_max_2018
# Out:
# (39.170244, 39.177513, 39.170151, 39.176993)

# %%
y_min_20161
# Out:
# 47.027841

# %%
x_min, x_max, y_min, y_max
# Out:
# (39.170244, 39.176993, 47.027841, 47.031657)

# %%
x = x_min + (x_max-x_min) / 2
y = y_min + (y_max-y_min) / 2

# %%
delta = (((x_max-x_min) *(y_max - y_min)) * 500 / 6206696 ) ** 0.5
delta
# Out:
# 4.5548980627186256e-05

# %%
(x_max - x_min) * 20004274 / 180
# Out:
# 750.0491401451483

# %%
(y_max - y_min) * 40075000 / 360 * (2 ** 0.5) / 2
# Out:
# 300.3754251141777

# %%
delta * 40075000 / 360 * (2 ** 0.5) / 2
# Out:
# 3.585375896070958

# %%
delta * 20004274 * 2 / 180
# Out:
# 10.124158765410286

# %%
x_2016 = vect_2016[:, 0]
x_2016_idx = np.array([(x_2016 >= x - delta) & (x_2016 <= x + delta)]).reshape(-1, )

y_2016 = vect_2016[:, 1]
y_2016_idx = np.array([(y_2016 >= y - delta) & (y_2016 <= y + delta)]).reshape(-1, )

x_2018 = vect_2018[:, 0]
x_2018_idx = np.array([(x_2018 >= x - delta) & (x_2018 <= x + delta)]).reshape(-1, )

y_2018= vect_2018[:, 1]
y_2018_idx = np.array([(y_2018 >= y - delta) & (y_2018 <= y + delta)]).reshape(-1, )

vect_2016_part = vect_2016[(x_2016_idx == True) & (y_2016_idx == True)]
vect_2018_part = vect_2018[(x_2018_idx == True) & (y_2018_idx == True)]
vect_2016_part.shape, vect_2018_part.shape
# Out:
# ((1134, 9), (2420, 9))

# %%
# %matplotlib inline  
import matplotlib.pyplot as plt
step  = 500000
first = 0
cl = ['rs', 'cs', 'ms', 'gs', 'ys', 'ks', 'bs']
fig = plt.figure(figsize=(20, 12))
ax = plt.subplot(111)
ax.plot(vect_2016_work[::500, 0], vect_2016_work[::500, 1], cl[0])

ax.plot(vect_2018_work[::500, 0], vect_2018_work[::500, 1], cl[1])

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend(['2016', '2018'])
ax.grid()

# %%
ans
# Out:
# [22]

# %%
# %matplotlib inline  
import matplotlib.pyplot as plt



cl = ['floralwhite', 'seashell','bisque', 'peachpuff','orange', 'darkorange', 'tomato', 'red', 'firebrick','brown', 'darkred']
leg = np.arange(0, 10)
fig = plt.figure(figsize=(20, 12))
ax = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax.legend(leg)
ax2.legend(leg)
ax.set_xlim(x_min - 5 * delta, x_max + 5 * delta)
ax.set_ylim(y_min - 5 * delta, y_max + 5 * delta)
ax2.set_xlim(x_min - 5 * delta, x_max + 5 * delta)
ax2.set_ylim(y_min - 5 * delta, y_max + 5 * delta)
ax.grid()
ax2.grid()




delta1 = delta 
for i in np.arange(x_min+delta1, x_max - delta1, delta1):
    x_2016_idx = np.array([(x_2016 >= i - delta1) & (x_2016 <= i + delta1)]).reshape(-1, )
    x_2018_idx = np.array([(x_2018 >= i - delta1) & (x_2018 <= i + delta1)]).reshape(-1, )

    for j in np.arange(y_min+delta1, y_max - delta1, delta1):
        y_2016_idx = np.array([(y_2016 >= j - delta1) & (y_2016 <= j + delta1)]).reshape(-1, )
        vect_2016_part = vect_2016[(x_2016_idx == True) & (y_2016_idx == True)]
        if (vect_2016_part[:, 2].shape[0] > 10):
            a = min(vect_2016_part[:, 2])
            b = max(vect_2016_part[:, 2])
            c = int(round(abs(a - b)))
            
            if (c >= 10):
                ax.scatter(vect_2016_part[::100, 0], vect_2016_part[::100, 1], c = 'darkred')
            else:
                ax.scatter(vect_2016_part[::100, 0], vect_2016_part[::100, 1], c = cl[c])
                
        y_2018_idx = np.array([(y_2018 >= j - delta1) & (y_2018 <= j + delta1)]).reshape(-1, )
        vect_2018_part = vect_2018[(x_2018_idx == True) & (y_2018_idx == True)]
        if (vect_2018_part[:, 2].shape[0] > 10):
            a = min(vect_2018_part[:, 2])
            b = max(vect_2018_part[:, 2])
            c = int(round(abs(a - b)))
            
            if (c >= 10):
                ax2.scatter(vect_2018_part[::100, 0], vect_2018_part[::100, 1], c = 'darkred')
            else:
                ax2.scatter(vect_2018_part[::100, 0], vect_2018_part[::100, 1], c = cl[c])
            
    
                

cl = ['floralwhite', 'seashell','bisque', 'peachpuff','orange', 'darkorange', 'tomato', 'red', 'firebrick','brown', 'darkred']

# %%
c
# Out:
# 11

# %%
cl = ['floralwhite', 'seashell', 'tomato', 'red', 'firebrick','brown', 'darked']

# %%
np.arange(y_min, y_max - delta1, delta1).shape
# Out:
# (837,)

# %%
np.arange(x_min, x_max, delta).shape
# Out:
# (149,)

# %%
np.arange(y_min, y_max - delta, delta)
# Out:
# array([47.027841  , 47.02788655, 47.0279321 , 47.02797765, 47.0280232 ,
#        47.02806874, 47.02811429, 47.02815984, 47.02820539, 47.02825094,
#        47.02829649, 47.02834204, 47.02838759, 47.02843314, 47.02847869,
#        47.02852423, 47.02856978, 47.02861533, 47.02866088, 47.02870643,
#        47.02875198, 47.02879753, 47.02884308, 47.02888863, 47.02893418,
#        47.02897972, 47.02902527, 47.02907082, 47.02911637, 47.02916192,
#        47.02920747, 47.02925302, 47.02929857, 47.02934412, 47.02938967,
#        47.02943521, 47.02948076, 47.02952631, 47.02957186, 47.02961741,
#        47.02966296, 47.02970851, 47.02975406, 47.02979961, 47.02984516,
#        47.0298907 , 47.02993625, 47.0299818 , 47.03002735, 47.0300729 ,
#        47.03011845, 47.030164  , 47.03020955, 47.0302551 , 47.03030064,
#        47.03034619, 47.03039174, 47.03043729, 47.03048284, 47.03052839,
#        47.03057394, 47.03061949, 47.03066504, 47.03071059, 47.03075613,
#        47.03080168, 47.03084723, 47.03089278, 47.03093833, 47.03098388,
#        47.03102943, 47.03107498, 47.03112053, 47.03116608, 47.03121162,
#        47.03125717, 47.03130272, 47.03134827, 47.03139382, 47.03143937,
#        47.03148492, 47.03153047, 47.03157602])

# %%
vect_2018_work[::500, 0]
# Out:
# array([39.171426, 39.171488, 39.171531, ..., 39.176031, 39.175999,
#        39.176026])

# %%
import matplotlib
matplotlib.use("TkAgg")
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg, NavigationToolbar2TkAgg
from matplotlib.figure import Figure
from mpl_toolkits.mplot3d import Axes3D

import tkinter as tk
from tkinter import ttk

import matplotlib.pyplot as plt
LARGE_FONT= ("Verdana", 12)

cl = ['rs', 'cs']


class SeaofBTCapp(tk.Tk):

    def __init__(self, *args, **kwargs):

        tk.Tk.__init__(self, *args, **kwargs)

        tk.Tk.iconbitmap(self)
        tk.Tk.wm_title(self, "Координаты облаков точек")


        container = tk.Frame(self)
        container.pack(side="top", fill="both", expand = True)
        container.grid_rowconfigure(0, weight=1)
        container.grid_columnconfigure(0, weight=1)

        self.frames = {}

        for F in (StartPage, PageOne, PageTwo, PageThree):

            frame = F(container, self)

            self.frames[F] = frame

            frame.grid(row=0, column=0, sticky="nsew")

        self.show_frame(StartPage)

    def show_frame(self, cont):

        frame = self.frames[cont]
        frame.tkraise()
        

    

class StartPage(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self,parent)
        label = tk.Label(self, text="Start Page", font=LARGE_FONT)
        label.pack(pady=10,padx=10)

        button = ttk.Button(self, text="Visit Page 1",
                            command=lambda: controller.show_frame(PageOne))
        button.pack()

        button2 = ttk.Button(self, text="Visit Page 2",
                            command=lambda: controller.show_frame(PageTwo))
        button2.pack()

        button3 = ttk.Button(self, text="Graph Page",
                            command=lambda: controller.show_frame(PageThree))
        button3.pack()


class PageOne(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = tk.Label(self, text="Page One!!!", font=LARGE_FONT)
        label.pack(pady=10,padx=10)

        button1 = ttk.Button(self, text="Back to Home",
                            command=lambda: controller.show_frame(PageThree))
        button1.pack()

        button2 = ttk.Button(self, text="Page Two",
                            command=lambda: controller.show_frame(PageTwo))
        button2.pack()


class PageTwo(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = tk.Label(self, text="Page Two!!!", font=LARGE_FONT)
        label.pack(pady=10,padx=10)

        button1 = ttk.Button(self, text="Back to Home",
                            command=lambda: controller.show_frame(PageThree))
        button1.pack()

        button2 = ttk.Button(self, text="Page One",
                            command=lambda: controller.show_frame(PageOne))
        button2.pack()


class PageThree(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = tk.Label(self, text="Координаты облаков точек 2016, 2018г.", font=LARGE_FONT)
        label.pack()

            
        
        def on_click(event):
            if event.inaxes is not None:
                print (event.xdata, event.ydata)
                self.x = event.xdata
                self.y = event.ydata
                
                
                
                
                
                
                x = self.x
                y = self.y
                
                
                x_2016 = vect_2016[:, 0]
                x_2016_idx = np.array([(x_2016 >= x - delta) & (x_2016 <= x + delta)]).reshape(-1, )

                y_2016 = vect_2016[:, 1]
                y_2016_idx = np.array([(y_2016 >= y - delta) & (y_2016 <= y + delta)]).reshape(-1, )

                x_2018 = vect_2018[:, 0]
                x_2018_idx = np.array([(x_2018 >= x - delta) & (x_2018 <= x + delta)]).reshape(-1, )

                y_2018= vect_2018[:, 1]
                y_2018_idx = np.array([(y_2018 >= y - delta) & (y_2018 <= y + delta)]).reshape(-1, )

                vect_2016_part = vect_2016[(x_2016_idx == True) & (y_2016_idx == True)]
                vect_2018_part = vect_2018[(x_2018_idx == True) & (y_2018_idx == True)]
                vect_2016_part.shape, vect_2018_part.shape
                
                
                
                a[1].clear()
                m6 = np.mean(vect_2016_part[:,2])
                m8 = np.mean(vect_2018_part[:,2])

                
                z1 = np.min(vect_2016_part[:,2])
                z2 = np.min(vect_2018_part[:,2])
                z3 = np.min(vect_2018_part[:,2] + m6 - m8)
                
                z_min = min(z1, z2, z3)
                
                
                z1 = np.max(vect_2016_part[:,2])
                z2 = np.max(vect_2018_part[:,2])
                z3 = np.max(vect_2018_part[:,2] + m6 - m8)
                
                z_max = max(z1, z2, z3)

                
                a[1].scatter(vect_2016_part[:,0], vect_2016_part[:,1], vect_2016_part[:,2])
                a[1].scatter(vect_2018_part[:,0], vect_2018_part[:,1], vect_2018_part[:,2])
                a[1].set_zlim(z_min, z_max)
                a[1].set_xlabel('x, широта')
                a[1].set_ylabel('y, долгота')
                a[1].set_zlabel('z, высота, м')
                a[1].legend(['2016', '2018'], loc='upper left')

                xax = a[1].xaxis   # или xax = ax.get_xaxis()
                xlocs = xax.get_ticklocs()
                a[1].set_xticklabels(str(np.around(xlocs, 5))[1:-1].split())



                yax = a[1].yaxis   # или xax = ax.get_xaxis()
                ylocs = yax.get_ticklocs()
                a[1].set_yticklabels(str(np.around(ylocs, 5))[1:-1].split())
                

                a[1].grid()
                
                toolbar.update()
                canvas._tkcanvas.pack( expand=True)
                canvas.mpl_connect('button_press_event', on_click)

                                
                a[2].clear()
                

                a[2].scatter(vect_2016_part[:,0], vect_2016_part[:,1], vect_2016_part[:,2])
                a[2].scatter(vect_2018_part[:,0], vect_2018_part[:,1], vect_2018_part[:,2] + m6 - m8)
                a[2].set_zlim(z_min, z_max)

                a[2].set_xlabel('x, широта')
                a[2].set_ylabel('y, долгота')
                a[2].set_zlabel('z, высота, м')
                a[1].set_title("Участок облаков точек в пространстве")
                a[2].set_title("Участок облаков точек в пространстве \n с подгонкой высот по среднему значению")

                #a[2].legend(['2016', '2018'], loc='left')
                
                xax = a[2].xaxis   # или xax = ax.get_xaxis()
                xlocs = xax.get_ticklocs()
                a[2].set_xticklabels(str(np.around(xlocs, 5))[1:-1].split())



                yax = a[2].yaxis   # или xax = ax.get_xaxis()
                ylocs = yax.get_ticklocs()
                a[2].set_yticklabels(str(np.around(ylocs, 5))[1:-1].split())
                a[2].grid()
                
 
                
                canvas.draw()

                toolbar.update()
                canvas._tkcanvas.pack( expand=True)
                canvas.mpl_connect('button_press_event', on_click)


            else:
                print ('Clicked ouside axes bounds but inside plot window')
                
    
    
        #f = Figure(figsize=(18,9))
        a = [None, None, None]
        
        f = plt.figure(figsize=(30, 5))
        from matplotlib import gridspec
        matplotlib.rc('xtick', labelsize=9) 
        matplotlib.rc('ytick', labelsize=9) 

        gs = gridspec.GridSpec(1, 3, width_ratios=[1, 1.5, 1.5]) 
        gs[2]
        
        a[1] = f.add_subplot(gs[1], projection = '3d')
        a[2] = f.add_subplot(gs[2], projection = '3d')

        a[0] = f.add_subplot(gs[0])
        
        
        a[0].plot(vect_2016_work[::1000, 0], vect_2016_work[::1000, 1], cl[0])

        a[0].plot(vect_2018_work[::1000, 0], vect_2018_work[::1000, 1], cl[1])
 



        a[0].set_xlabel('x, широта')
        a[0].set_ylabel('y, долгота')
        a[0].legend(['2016', '2018'])
        a[0].grid()
        a[0].set_title("Облака точек на плоскости Oxy. \n Размер области порядка ")
        
        xax = a[0].xaxis   # или xax = ax.get_xaxis()
        xlocs = xax.get_ticklocs()
        a[0].set_xticks(xlocs[::2])
 
        canvas = FigureCanvasTkAgg(f, self)
        canvas.draw()
        canvas.get_tk_widget().pack(side=tk.BOTTOM, fill=tk.BOTH, expand=True)

        toolbar = NavigationToolbar2TkAgg(canvas, self)
        toolbar.update()
        canvas._tkcanvas.pack( expand=True)


        canvas.mpl_connect('button_press_event', on_click)




app = SeaofBTCapp()
app.mainloop()
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:268: MatplotlibDeprecationWarning: The NavigationToolbar2TkAgg class was deprecated in version 2.2.
# 39.17492521575199 47.03021515857143
# 39.1733767593688 47.03006303857143
# 39.17325035476609 47.02935676714286
# 39.17394558008099 47.028672227142856
# 39.17596805372434 47.02895473571429
# 39.176378868683145 47.02992178428571
# 39.175652042217564 47.030541129999996
# 39.17293434325932 47.030475935714286
# 39.17138588687613 47.02992178428571
# 39.17208111219103 47.028846078571426
# 39.17489361460131 47.02857443571428
# 39.17464080539589 47.030019575714284
# 39.17606285717637 47.03082363857143
# 39.174166788135736 47.03074757857143
# 39.173187152464735 47.03056286142857
# 39.171891505286965 47.03023689
# 39.170975071917326 47.03041074142857
# C:\anaconda\lib\site-packages\numpy\core\fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\anaconda\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Traceback (most recent call last):
#   File "C:\anaconda\lib\site-packages\matplotlib\cbook\__init__.py", line 388, in process
#     proxy(*args, **kwargs)
#   File "C:\anaconda\lib\site-packages\matplotlib\cbook\__init__.py", line 228, in __call__
#     return mtd(*args, **kwargs)
#   File "<ipython-input-42-7e4992ce2c5a>", line 150, in on_click
#     z1 = np.min(vect_2016_part[:,2])
#   File "C:\anaconda\lib\site-packages\numpy\core\fromnumeric.py", line 2420, in amin
#     out=out, **kwargs)
#   File "C:\anaconda\lib\site-packages\numpy\core\_methods.py", line 29, in _amin
#     return umr_minimum(a, axis, None, out, keepdims)
# ValueError: zero-size array to reduction operation minimum which has no identity
# 39.170975071917326 47.03041074142857
# Traceback (most recent call last):
#   File "C:\anaconda\lib\site-packages\matplotlib\cbook\__init__.py", line 388, in process
#     proxy(*args, **kwargs)
#   File "C:\anaconda\lib\site-packages\matplotlib\cbook\__init__.py", line 228, in __call__
#     return mtd(*args, **kwargs)
#   File "<ipython-input-42-7e4992ce2c5a>", line 150, in on_click
#     z1 = np.min(vect_2016_part[:,2])
#   File "C:\anaconda\lib\site-packages\numpy\core\fromnumeric.py", line 2420, in amin
#     out=out, **kwargs)
#   File "C:\anaconda\lib\site-packages\numpy\core\_methods.py", line 29, in _amin
#     return umr_minimum(a, axis, None, out, keepdims)
# ValueError: zero-size array to reduction operation minimum which has no identity
# 39.17362956857422 47.03093229571429
# 39.173313557067445 47.029541484285716
# 39.17173349953358 47.02946542428571
# 39.174008782382344 47.029487155714286
# 39.17375597317693 47.030475935714286
# 39.175209626108085 47.030356412857145
# 39.17429319273844 47.03109528142857
# 39.172491927149835 47.030649787142856
# Traceback (most recent call last):
#   File "C:\anaconda\lib\site-packages\matplotlib\cbook\__init__.py", line 388, in process
#     proxy(*args, **kwargs)
#   File "C:\anaconda\lib\site-packages\matplotlib\cbook\__init__.py", line 228, in __call__
#     return mtd(*args, **kwargs)
#   File "<ipython-input-42-7e4992ce2c5a>", line 150, in on_click
#     z1 = np.min(vect_2016_part[:,2])
#   File "C:\anaconda\lib\site-packages\numpy\core\fromnumeric.py", line 2420, in amin
#     out=out, **kwargs)
#   File "C:\anaconda\lib\site-packages\numpy\core\_methods.py", line 29, in _amin
#     return umr_minimum(a, axis, None, out, keepdims)
# ValueError: zero-size array to reduction operation minimum which has no identity
# 39.17173349953358 47.03044333857143
# 39.171986308739 47.03009563571428
# 39.17350316397151 47.02950888714285
# 39.17716889745007 47.029432827142855
# Traceback (most recent call last):
#   File "C:\anaconda\lib\site-packages\matplotlib\cbook\__init__.py", line 388, in process
#     proxy(*args, **kwargs)
#   File "C:\anaconda\lib\site-packages\matplotlib\cbook\__init__.py", line 228, in __call__
#     return mtd(*args, **kwargs)
#   File "<ipython-input-42-7e4992ce2c5a>", line 150, in on_click
#     z1 = np.min(vect_2016_part[:,2])
#   File "C:\anaconda\lib\site-packages\numpy\core\fromnumeric.py", line 2420, in amin
#     out=out, **kwargs)
#   File "C:\anaconda\lib\site-packages\numpy\core\_methods.py", line 29, in _amin
#     return umr_minimum(a, axis, None, out, keepdims)
# ValueError: zero-size array to reduction operation minimum which has no identity
# 39.17628406523111 47.02945455857143
# 39.17596805372434 47.03023689
# 39.17628406523111 47.028976467142854
# 39.17631566638179 47.029367632857145
# 39.1771372962994 47.02975879857143
# Traceback (most recent call last):
#   File "C:\anaconda\lib\site-packages\matplotlib\cbook\__init__.py", line 388, in process
#     proxy(*args, **kwargs)
#   File "C:\anaconda\lib\site-packages\matplotlib\cbook\__init__.py", line 228, in __call__
#     return mtd(*args, **kwargs)
#   File "<ipython-input-42-7e4992ce2c5a>", line 150, in on_click
#     z1 = np.min(vect_2016_part[:,2])
#   File "C:\anaconda\lib\site-packages\numpy\core\fromnumeric.py", line 2420, in amin
#     out=out, **kwargs)
#   File "C:\anaconda\lib\site-packages\numpy\core\_methods.py", line 29, in _amin
#     return umr_minimum(a, axis, None, out, keepdims)
# ValueError: zero-size array to reduction operation minimum which has no identity
# 39.17653687443653 47.029791395714284
# 39.172270719095096 47.03062805571429
# Traceback (most recent call last):
#   File "C:\anaconda\lib\site-packages\matplotlib\cbook\__init__.py", line 388, in process
#     proxy(*args, **kwargs)
#   File "C:\anaconda\lib\site-packages\matplotlib\cbook\__init__.py", line 228, in __call__
#     return mtd(*args, **kwargs)
#   File "<ipython-input-42-7e4992ce2c5a>", line 150, in on_click
#     z1 = np.min(vect_2016_part[:,2])
#   File "C:\anaconda\lib\site-packages\numpy\core\fromnumeric.py", line 2420, in amin
#     out=out, **kwargs)
#   File "C:\anaconda\lib\site-packages\numpy\core\_methods.py", line 29, in _amin
#     return umr_minimum(a, axis, None, out, keepdims)
# ValueError: zero-size array to reduction operation minimum which has no identity
# 39.171796701834936 47.03044333857143
# 39.174040383533026 47.03098662428572
# 39.176473672135174 47.02905252714286
# 39.1761576606284 47.028976467142854
# 39.171575493780196 47.03058459285714
# Traceback (most recent call last):
#   File "C:\anaconda\lib\site-packages\matplotlib\cbook\__init__.py", line 388, in process
#     proxy(*args, **kwargs)
#   File "C:\anaconda\lib\site-packages\matplotlib\cbook\__init__.py", line 228, in __call__
#     return mtd(*args, **kwargs)
#   File "<ipython-input-42-7e4992ce2c5a>", line 150, in on_click
#     z1 = np.min(vect_2016_part[:,2])
#   File "C:\anaconda\lib\site-packages\numpy\core\fromnumeric.py", line 2420, in amin
#     out=out, **kwargs)
#   File "C:\anaconda\lib\site-packages\numpy\core\_methods.py", line 29, in _amin
#     return umr_minimum(a, axis, None, out, keepdims)
# ValueError: zero-size array to reduction operation minimum which has no identity
# 39.17182830298562 47.03055199571428
# 39.172713135204575 47.03067151857143
# 39.173218753615416 47.03087796714286
# Traceback (most recent call last):
#   File "C:\anaconda\lib\site-packages\matplotlib\cbook\__init__.py", line 388, in process
#     proxy(*args, **kwargs)
#   File "C:\anaconda\lib\site-packages\matplotlib\cbook\__init__.py", line 228, in __call__
#     return mtd(*args, **kwargs)
#   File "<ipython-input-42-7e4992ce2c5a>", line 150, in on_click
#     z1 = np.min(vect_2016_part[:,2])
#   File "C:\anaconda\lib\site-packages\numpy\core\fromnumeric.py", line 2420, in amin
#     out=out, **kwargs)
#   File "C:\anaconda\lib\site-packages\numpy\core\_methods.py", line 29, in _amin
#     return umr_minimum(a, axis, None, out, keepdims)
# ValueError: zero-size array to reduction operation minimum which has no identity
# 39.17362956857422 47.03082363857143
# 39.17397718123167 47.03098662428572
# 39.174862013450635 47.03120393857143
# 39.171670297232225 47.03038901
# 39.170753863862586 47.03028035285714
# 39.172965944409995 47.03018256142857
# 39.174704007697244 47.02986745571428
# 39.175051620354694 47.029769664285716
# 39.17558883991621 47.02983485857143
# 39.17558883991621 47.02997611285714
# 39.17574684566959 47.03010650142857
# 39.175778446820274 47.029150318571425
# 39.17441959734115 47.029258975714285
# 39.175051620354694 47.029258975714285
# 39.17502001920402 47.02924811
# 39.17445119849183 47.02983485857143
# 39.175083221505375 47.02958494714286
# 39.17511482265605 47.029791395714284
# 39.175304429560114 47.03011736714286
# 39.171986308739 47.02912858714286
# 39.171986308739 47.02953061857143
# 39.174040383533026 47.02986745571428
# 39.174956816902665 47.02916118428571
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-7e4992ce2c5a> in <module>()
#     277
#     278 app = SeaofBTCapp()
# --> 279 app.mainloop()
#
# C:\anaconda\lib\tkinter\__init__.py in mainloop(self, n)
#    1278     def mainloop(self, n=0):
#    1279         """Call the mainloop of Tk."""
# -> 1280         self.tk.mainloop(n)
#    1281     def quit(self):
#    1282         """Quit the Tcl interpreter. All widgets will be destroyed."""
#
# KeyboardInterrupt:

# %%
a = [None, None]

# %%
a[0] = 1
a[1] = 2

# %%
39.17608911580645 47.029205350735836

# %%
vect_2016[vect_2016[:, 2] < 0].shape
# Out:
# (276297, 9)

# %%
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(121, projection = '3d')
ax2 = fig.add_subplot(122)
ax.scatter(vect_2016_part[:,0], vect_2016_part[:,1], vect_2016_part[:,2])



xax = ax.xaxis   # или xax = ax.get_xaxis()
xlocs = xax.get_ticklocs()
ax.set_xticklabels(str(np.around(xlocs, 5))[1:-1].split())



yax = ax.yaxis   # или xax = ax.get_xaxis()
ylocs = yax.get_ticklocs()
ax.set_yticklabels(str(np.around(ylocs, 5))[1:-1].split())
# Out:
# [Text(0,0,'47.02968'),
#  Text(0,0,'47.0297'),
#  Text(0,0,'47.02972'),
#  Text(0,0,'47.02974'),
#  Text(0,0,'47.02976'),
#  Text(0,0,'47.02978'),
#  Text(0,0,'47.0298')]
